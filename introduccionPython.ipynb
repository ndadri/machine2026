# %% [markdown]
# ## Introduccion a Python

# %% [markdown]
# <img src= "img/LogoITQ.png" width="250px"/><br>
# **Nombre:** *Adrian Gabriel Lesly*<br>
# **Fecha:** *7/Enero/2026*

# %%
#Comentario de python
print("Esto es Python")
print("Esto no ")
# Out:
# Esto es Python
